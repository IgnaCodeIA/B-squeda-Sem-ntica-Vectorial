# %% [markdown]
# # Uso de modelos de embeddings de OpenAI

# %% [markdown]
# ## Instalación y carga de librerías

# %%
# !pip install openai
# !pip install tiktoken
# Out:
# Requirement already satisfied: openai in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (1.13.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from openai) (2.6.3)
# Requirement already satisfied: sniffio in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Requirement already satisfied: tiktoken in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (0.6.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from tiktoken) (2023.10.3)
# Requirement already satisfied: requests>=2.26.0 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ignaciocarrenoromero/anaconda3/envs/Pytorch_DL/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken) (2024.2.2)

# %%
from openai import OpenAI
from getpass import getpass
import os
import pandas as pd

# %%
client = OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ## Cargar dataset

# %%
df = pd.read_csv('../Corpus/generic-food.csv')

# %%
df.head()
# Out:
#         FOOD NAME                 SCIENTIFIC NAME             GROUP  \
# 0        Angelica                Angelica keiskei  Herbs and Spices
# 1   Savoy cabbage  Brassica oleracea var. sabauda        Vegetables
# 2   Silver linden                  Tilia argentea  Herbs and Spices
# 3            Kiwi             Actinidia chinensis            Fruits
# 4  Allium (Onion)                          Allium        Vegetables
#
#                  SUB GROUP
# 0                    Herbs
# 1                 Cabbages
# 2                    Herbs
# 3          Tropical fruits
# 4  Onion-family vegetables

# %% [markdown]
# ## Evaluar cantidad de tokens a procesar

# %%
import tiktoken

# %%
def calcular_tokens(text,embedding_model):
    modelo = tiktoken.get_encoding(embedding_model)
    token = len(modelo.encode(text))
    return token

# %%
df['tokens totales'] = df['FOOD NAME'].apply(lambda x: calcular_tokens(x, 'cl100k_base'))

# %%
df
# Out:
#            FOOD NAME                                    SCIENTIFIC NAME  \
# 0           Angelica                                   Angelica keiskei
# 1      Savoy cabbage                     Brassica oleracea var. sabauda
# 2      Silver linden                                     Tilia argentea
# 3               Kiwi                                Actinidia chinensis
# 4     Allium (Onion)                                             Allium
# ..               ...                                                ...
# 901    White cabbage  Brassica oleracea L. var. capitata L. f. alba DC.
# 902  Romaine lettuce                  Lactuca sativa L. var. longifolia
# 903        dumplings                                                NaN
# 904           muesli                                                NaN
# 905             milk                                                NaN
#
#                 GROUP                SUB GROUP  tokens totales
# 0    Herbs and Spices                    Herbs               2
# 1          Vegetables                 Cabbages               4
# 2    Herbs and Spices                    Herbs               3
# 3              Fruits          Tropical fruits               2
# 4          Vegetables  Onion-family vegetables               6
# ..                ...                      ...             ...
# 901        Vegetables                 Cabbages               2
# 902        Vegetables          Leaf vegetables               4
# 903               NaN                      NaN               3
# 904               NaN                      NaN               3
# 905               NaN                      NaN               2
#
# [906 rows x 5 columns]

# %%
sum(df['tokens totales'])
# Out:
# 2951

# %% [markdown]
# ## Generando emebeddings

# %%
def get_embedding(text, model = "text-embedding-ada-002"):
  text = text.replace('\n', '')
  response = client.embeddings.create(
      input=text,
      model=model
  )
  return response.data[0].embedding

# %%
df["ada_embedding"] = df["FOOD NAME"].apply(lambda x: get_embedding(x))

# %%
df
# Out:
#            FOOD NAME                                    SCIENTIFIC NAME  \
# 0           Angelica                                   Angelica keiskei
# 1      Savoy cabbage                     Brassica oleracea var. sabauda
# 2      Silver linden                                     Tilia argentea
# 3               Kiwi                                Actinidia chinensis
# 4     Allium (Onion)                                             Allium
# ..               ...                                                ...
# 901    White cabbage  Brassica oleracea L. var. capitata L. f. alba DC.
# 902  Romaine lettuce                  Lactuca sativa L. var. longifolia
# 903        dumplings                                                NaN
# 904           muesli                                                NaN
# 905             milk                                                NaN
#
#                 GROUP                SUB GROUP  tokens totales  \
# 0    Herbs and Spices                    Herbs               2
# 1          Vegetables                 Cabbages               4
# 2    Herbs and Spices                    Herbs               3
# 3              Fruits          Tropical fruits               2
# 4          Vegetables  Onion-family vegetables               6
# ..                ...                      ...             ...
# 901        Vegetables                 Cabbages               2
# 902        Vegetables          Leaf vegetables               4
# 903               NaN                      NaN               3
# 904               NaN                      NaN               3
# 905               NaN                      NaN               2
#
#                                          ada_embedding
# 0    [0.00622481619939208, -0.010139460675418377, 0...
# 1    [0.005467566661536694, -0.004983342252671719, ...
# 2    [-0.0044629997573792934, 0.020091881975531578,...
# 3    [-0.004675016738474369, -0.010036393068730831,...
# 4    [0.013209687545895576, -0.019948789849877357, ...
# ..                                                 ...
# 901  [0.010564504191279411, -0.01918477937579155, 0...
# 902  [-0.0033427441958338022, -0.012237627059221268...
# 903  [0.00377720152027905, -0.013168713077902794, 0...
# 904  [-0.01571560464799404, -0.015782881528139114, ...
# 905  [0.0008577064145356417, -0.019351031631231308,...
#
# [906 rows x 6 columns]

# %%
# exportar el dataframe
df.to_csv('generic-food-embeddings.csv', index=False)

# %% [markdown]
# ## Creando datasets para visualizar

# %%
df = pd.read_csv('generic-food-embeddings_ada.csv')
df.head()
# Out:
#         FOOD NAME                 SCIENTIFIC NAME             GROUP  \
# 0        Angelica                Angelica keiskei  Herbs and Spices
# 1   Savoy cabbage  Brassica oleracea var. sabauda        Vegetables
# 2   Silver linden                  Tilia argentea  Herbs and Spices
# 3            Kiwi             Actinidia chinensis            Fruits
# 4  Allium (Onion)                          Allium        Vegetables
#
#                  SUB GROUP  tokens totales  \
# 0                    Herbs               2
# 1                 Cabbages               4
# 2                    Herbs               3
# 3          Tropical fruits               2
# 4  Onion-family vegetables               6
#
#                                        ada_embedding
# 0  [0.00622481619939208, -0.010139460675418377, 0...
# 1  [0.005467566661536694, -0.004983342252671719, ...
# 2  [-0.0044629997573792934, 0.020091881975531578,...
# 3  [-0.004675016738474369, -0.010036393068730831,...
# 4  [0.013209687545895576, -0.019948789849877357, ...

# %%
df_embeddgins = pd.DataFrame(list(df['ada_embedding']))
df_embeddgins.head()
# Out:
#                                                    0
# 0  [0.00622481619939208, -0.010139460675418377, 0...
# 1  [0.005467566661536694, -0.004983342252671719, ...
# 2  [-0.0044629997573792934, 0.020091881975531578,...
# 3  [-0.004675016738474369, -0.010036393068730831,...
# 4  [0.013209687545895576, -0.019948789849877357, ...

# %%
df_embeddgins.to_csv('embeddings_food.tsv',sep='\t',index=False,header=False)

# %%
df[['FOOD NAME', 'GROUP', 'SUB GROUP']].to_csv('metadata_food.tsv',sep='\t',index=False,header=False)
